# %% [markdown]
# # Logistic Regression with SkLearn
#
# In this report, i will explain the model that i implemented to classify signs traffic signs. I used a model based in logistic regression with L2 regularization, multinomial with LBFS optimization. I will introduce you in this terms. L2 regularization use the hyperparameter Lambda. This parameter allows to reduce the overfitting obtaining a better precision in the test data. In adittion, the LBFS optimization allow to use L2 regularization (see Scikit-Learn documentation). The multinomial models are very communly used in classifying more than two different labels.
#
# Next, i will explain you slightly the code that i did. The complete code can be found in models folder as model1
#
# First, i will import the main packages to use them in the next step.

# %%
import os
from sklearn.externals import joblib
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Second, i am defining the models parameters tha i will use (explained above - first paragraph)

# %%
lg = LogisticRegression(penalty='l2', multi_class='multinomial', solver='lbfgs')

# %% [markdown]
# In oder to obtain the weights, we need fit the model.

# %%
lg.fit(xdata, ydata). #The data must be preproccesed and introduce them as parameter
# Out:
#   File "<ipython-input-5-2559274885a9>", line 1
#     lg.fit(xdata, ydata). #The data must be preproccesed and introduce them as parameter
#                                                                                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# After, we save and load the weights. we use them to validate the model with test data and we can get the accuracy.

# %%
joblib.dump(lg, './models/model1/saved/LogRskLearn.pkl')
lg = joblib.load(os.path.abspath('models/model1/saved/LogRskLearn.pkl'))
y_modelo = lg.predict(X_data)
accuracy = accuracy_score(Y_data, y_modelo) * 100
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-dfc05d1400b3> in <module>()
# ----> 1 joblib.dump(lg, './models/model1/saved/LogRskLearn.pkl')
#       2 lg = joblib.load(os.path.abspath('models/model1/saved/LogRskLearn.pkl'))
#       3 y_modelo = lg.predict(X_data)
#       4 accuracy = accuracy_score(Y_data, y_modelo) * 100
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/externals/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     481             NumpyPickler(f, protocol=protocol).dump(value)
#     482     elif is_filename:
# --> 483         with open(filename, 'wb') as f:
#     484             NumpyPickler(f, protocol=protocol).dump(value)
#     485     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './models/model1/saved/LogRskLearn.pkl'

# %% [markdown]
# The accuracy of this model was 75.68% . Dependig of the accuracy, we should modify the hyperparametres or get more data. In the last step, we use the model to predict new images. (I choose three random images).

# %% [markdown]
# ![Screen%20Shot%202018-10-04%20at%2010.45.41%20AM.png](attachment:Screen%20Shot%202018-10-04%20at%2010.45.41%20AM.png)
#
# ![Screen%20Shot%202018-10-04%20at%2010.45.51%20AM.png](attachment:Screen%20Shot%202018-10-04%20at%2010.45.51%20AM.png)
#
# ![Screen%20Shot%202018-10-04%20at%2010.46.03%20AM.png](attachment:Screen%20Shot%202018-10-04%20at%2010.46.03%20AM.png)
